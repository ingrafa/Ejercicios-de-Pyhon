# %% [markdown]
# <a href="https://colab.research.google.com/github/ingrafa/Ejercicios-de-Pyhon/blob/main/Aprendiendo_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Tiene formato de código
#
# ###Aprendiendo Python
# ```

# %%
# !pip install numpy

import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print("El arreglo:", arr)
print("La suma de los elementos del arreglo:", np.sum(arr))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# El arreglo: [1 2 3 4 5]
# La suma de los elementos del arreglo: 15

# %%
import cv2
from google.colab import files
import matplotlib.pyplot as plt

# Cargar la imagen desde el sistema local
uploaded = files.upload()

# Leer la imagen utilizando OpenCV
image_path = list(uploaded.keys())[0]
image = cv2.imread(image_path)

# Convertir la imagen de BGR a RGB (para mostrarla con matplotlib)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Mostrar la imagen original
plt.figure(figsize=(8, 6))
plt.imshow(image_rgb)
plt.title("Imagen original")
plt.axis("off")
plt.show()

# Cambiar el color de la imagen a escala de grises
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Mostrar la imagen en escala de grises
plt.figure(figsize=(8, 6))
plt.imshow(gray_image, cmap="gray")
plt.title("Imagen en escala de grises")
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-74404cbd-13b1-4047-8536-eb4a41ab3468" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74404cbd-13b1-4047-8536-eb4a41ab3468">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
